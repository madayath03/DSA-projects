# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Loading the data in the book

# %%
data = pd.read_excel('C:/Users/HARIKRISHNAN M/Downloads/iris.xls')
data.head()
# Out:
#     SL   SW   PL   PW Classification
# 0  5.1  3.5  1.4  0.2    Iris-setosa
# 1  4.9  3.0  1.4  0.2    Iris-setosa
# 2  4.7  3.2  1.3  0.2    Iris-setosa
# 3  4.6  3.1  1.5  0.2    Iris-setosa
# 4  5.0  3.6  1.4  0.2    Iris-setosa

# %% [markdown]
# # checking complete data to know the end of data

# %%
data
# Out:
#       SL   SW   PL   PW  Classification
# 0    5.1  3.5  1.4  0.2     Iris-setosa
# 1    4.9  3.0  1.4  0.2     Iris-setosa
# 2    4.7  3.2  1.3  0.2     Iris-setosa
# 3    4.6  3.1  1.5  0.2     Iris-setosa
# 4    5.0  3.6  1.4  0.2     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 145  6.7  3.0  5.2  2.3  Iris-virginica
# 146  6.3  2.5  5.0  1.9  Iris-virginica
# 147  6.5  3.0  5.2  2.0  Iris-virginica
# 148  6.2  3.4  5.4  2.3  Iris-virginica
# 149  5.9  3.0  5.1  1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# # finding the mean of each coloumn of data

# %%
np.mean(data['SL'])
# Out:
# 3.0540000000000007

# %%
np.mean(data['SW'])
# Out:
# 3.0540000000000007

# %%
np.mean(data['PL'])
# Out:
# 3.7586666666666693

# %%
np.mean(data['PW'])
# Out:
# 1.1986666666666672

# %% [markdown]
# # ploting to check its distribution

# %%
data[['SL','SW','PL','PW']].plot.kde()
# Out:
# <AxesSubplot:ylabel='Density'>

# %% [markdown]
# # the plots shows normal distribution
# # checking null values in all the columns

# %%
pd.isna(data['Classification']).any()
# Out:
# False

# %%
data['SL'].isna().any()
# Out:
# False

# %%
data['SW'].isna().any()
# Out:
# False

# %%
data['PL'].isna().any()
# Out:
# False

# %%
data['PW'].isna().any()
# Out:
# False

# %% [markdown]
# # since above all outputs are false, it means there is no null values in any columns.
# # we can go ahead with plots

# %%
sns.heatmap(data[['SL','SW']].corr(),annot = True)
# Out:
# <AxesSubplot:>

# %%
plt.subplot(1,2,1)
plt.scatter(data['SL'],data['SW'],color = 'red', marker = '*')

plt.subplot(1,2,2)
plt.scatter(data['PL'],data['PW'],marker = '^')

# %% [markdown]
# # for SL and SW there is no correlation observed as all points are crowded
# # for PL an PW there is a linear correlation where as PL increases PW also increases

# %%
sns.pairplot(data)

# %%
plt.subplot(1,2,1)
sns.boxplot(x='SL',y='SW',hue='Classification',data= data)
plt.xticks(rotation=90)

plt.subplot(1,2,2)
sns.boxplot(x='PL',y='PW',hue='Classification',data= data)
# Out:
# <AxesSubplot:xlabel='PL', ylabel='PW'>

# %%
data['Classification'].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %% [markdown]
# # Distribution of sepal length

# %%
plt.figure(figsize=(4,4))
plt.hist(data['SL'],color='green', rwidth=0.6)
plt.title('Distribution of Sepal length')
plt.xlabel('Sepal length')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %% [markdown]
# # Distribution of sepal width

# %%
plt.figure(figsize=(4,4))
plt.hist(data['SW'],color='red', rwidth=0.6)
plt.title('Distribution of Sepal width')
plt.xlabel('Sepal width')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %% [markdown]
# # Distribution of petal length

# %%
plt.figure(figsize=(4,4))
plt.hist(data['PL'],color='blue', rwidth=0.6)
plt.title('Distribution of petal length')
plt.xlabel('Petal length')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %% [markdown]
# # Distribution of petal width

# %%
plt.figure(figsize=(4,4))
plt.hist(data['PW'],color='yellow', rwidth=0.6)
plt.title('Distribution of petal width')
plt.xlabel('Petal width')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %% [markdown]
# # The above 4 graphs highlight the distribution of SL,SW,PL and PW in the population
